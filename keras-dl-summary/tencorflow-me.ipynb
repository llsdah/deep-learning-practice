# %%
import tensorflow as tf

print('ten ',tf.__version__)

x = tf.linspace(0,1,5)
print(x)
print(type(x), x.shape, x.dtype) #
# Out:
# ten  2.20.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776671244.046601   16574 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6094 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070, pci bus id: 0000:01:00.0, compute capability: 7.5
# tf.Tensor([0.   0.25 0.5  0.75 1.  ], shape=(5,), dtype=float64)
# <class 'tensorflow.python.framework.ops.EagerTensor'> (5,) <dtype: 'float64'>
